# %% [markdown]
# <a href="https://colab.research.google.com/github/Umeshtheru/green-hydrogen/blob/main/Gold_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
gold_data=pd.read_csv('/content/gld_price_data.csv')
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
X=gold_data.drop(['Date','GLD'],axis=1)
Y=gold_data['GLD']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
model= RandomForestRegressor(n_estimators=100)
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
X_test_prediction =model.predict(X_test)
error_score=metrics.r2_score(Y_test,X_test_prediction)
error_score
# Out:
# 0.9887505111984805

# %%
Y_test=list(Y_test)
plt.plot(Y_test, color='blue',label='Actual Value')
plt.plot(X_test_prediction, color='red',label='Predicted_value')
plt.title('Actual vs Prediction')
plt.xlabel('Number of values')
plt.ylabel('Gold price')
plt.legend()
plt.show()
